# %%
cd /content/drive/MyDrive/SAR/SynDataGen
# Out:
# /content/drive/.shortcut-targets-by-id/1kCsuFHFfR6l5mt_YUZhVIiYR54XsyJB2/SAR/SynDataGen-Drive

# %%
import os, shutil
PROJECT_DIR = "/content/drive/MyDrive/SAR/private-bdi"

# ic ice git reposu kalintisi var mi kontrol et ve temizle (HarmoniDiff'in kendi .git'i gibi)
for root, dirs, files in os.walk(PROJECT_DIR):
    if root == PROJECT_DIR:
        continue  # ana klasorun kendi .git'i olacak, ona dokunma
    if ".git" in dirs:
        inner_git = os.path.join(root, ".git")
        print(f"Ic ice .git bulundu, siliniyor: {inner_git}")
        shutil.rmtree(inner_git)

gitignore_content = """
data/
outputs/
models/HarmoniDiff/checkpoints/
models/HarmoniDiff/demo/
models/HarmoniDiff/visualization*/
__pycache__/
.ipynb_checkpoints/
*.tif
*.pt
"""
with open(f"{PROJECT_DIR}/.gitignore", "w") as f:
    f.write(gitignore_content)
print("gitignore yazildi")

# %%
from google.colab import userdata
import subprocess

PROJECT_DIR = "/content/drive/MyDrive/SAR/private-bdi"
GITHUB_TOKEN = "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"
GITHUB_USERNAME = "melikeakdag"
REPO_NAME = "private-bdi"

def run(cmd, cwd=PROJECT_DIR):
    print(">>>", " ".join(cmd))
    result = subprocess.run(cmd, cwd=cwd, capture_output=True, text=True)
    print(result.stdout)
    if result.returncode != 0:
        print("HATA:", result.stderr)
    return result

run(["git", "init"])
run(["git", "config", "user.name", "Melike Akdag"])
run(["git", "config", "user.email", "melikecolak41@gmail.com"])

run(["git", "add", "-A"])
run(["git", "status"])  # BURAYA BAK: 'SynDataGen/' ya da baska bir klasor "does not have a commit" diye hala cikiyor mu kontrol et
# Out:
# >>> git init
# Reinitialized existing Git repository in /content/drive/.shortcut-targets-by-id/1kCsuFHFfR6l5mt_YUZhVIiYR54XsyJB2/SAR/private-bdi/.git/
#
# >>> git config user.name Melike Akdag
#
# >>> git config user.email melikecolak41@gmail.com
#
# >>> git add -A
#
# >>> git status
# On branch main
# nothing to commit, working tree clean
# CompletedProcess(args=['git', 'status'], returncode=0, stdout='On branch main\nnothing to commit, working tree clean\n', stderr='')

# %%
import subprocess

def run(cmd, cwd="/content/drive/MyDrive/SAR/private-bdi"):
    print(">>>", " ".join(cmd))
    result = subprocess.run(cmd, cwd=cwd, capture_output=True, text=True)
    print(result.stdout)
    if result.returncode != 0:
        print("HATA:", result.stderr)
    return result

run(["git", "add", "-A"])
run(["git", "status"])   # burada artik "Changes to be committed" gormen lazim, "Untracked files" degil
# Out:
# >>> git add -A
#
# >>> git status
# On branch main
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   notebooks/Untitled0.ipynb
# CompletedProcess(args=['git', 'status'], returncode=0, stdout='On branch main\nChanges to be committed:\n  (use "git restore --staged <file>..." to unstage)\n\tmodified:   notebooks/Untitled0.ipynb\n\n', stderr='')

# %%
run(["git", "commit", "-m", "v1: sentetik hasar veri uretim pipeline'i"])
run(["git", "push", "-u", "origin", "main"])
# Out:
# >>> git commit -m v1: sentetik hasar veri uretim pipeline'i
# [main 120e893] v1: sentetik hasar veri uretim pipeline'i
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite notebooks/Untitled0.ipynb (90%)
#
# >>> git push -u origin main
#
# HATA: remote: Repository not found.
# fatal: repository 'https://github.com/melikeakdag/SynDataGen.git/' not found
# CompletedProcess(args=['git', 'push', '-u', 'origin', 'main'], returncode=128, stdout='', stderr="remote: Repository not found.\nfatal: repository 'https://github.com/melikeakdag/SynDataGen.git/' not found\n")

# %% [markdown]
# EDA

# %%
cd /content/drive/MyDrive/SAR/SynDataGen-Drive
# Out:
# /content/drive/.shortcut-targets-by-id/1kCsuFHFfR6l5mt_YUZhVIiYR54XsyJB2/SAR/SynDataGen-Drive

# %%
ROOT="/content/drive/MyDrive/SAR/SynDataGen-Drive"

# %%
# %run {ROOT}/scripts/analyze_harmonized.py \
    --synthetic_dir {ROOT}/outputs/synthetic_pairs \
    --harmonized_dir {ROOT}/outputs/harmonized \
    --out_csv {ROOT}/outputs/eda_report.csv
# Out:
# harmonized/ icinde bulunan instance sayisi: 529
# Analiz edilebilen instance: 529
# CSV kaydedildi: /content/drive/MyDrive/SAR/SynDataGen-Drive/outputs/eda_report.csv
#
# === Genel ozet ===
#        mask_area_px_512  diff_in_mask_mean  diff_out_mask_mean  \
# count        529.000000         529.000000               529.0
# mean         629.385633         162.397771                 0.0
# std          640.578023          51.134829                 0.0
# min           49.000000          65.756757                 0.0
# 25%          219.000000         129.910526                 0.0
# 50%          454.000000         152.554301                 0.0
# 75%          846.000000         183.528662                 0.0
# max         5384.000000         446.334392                 0.0
#
#        changed_px_ratio_in_mask
# count                529.000000
# mean                   0.953952
# std                    0.021287
# min                    0.778926
# 25%                    0.943333
# ...
